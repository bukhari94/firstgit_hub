# %%
weight=input("enter your weight ")
weight=float(weight)
height=input("enter your height")
height=float(height)
name=input("what is your name")
BMI=weight/height**2
print("my name is :",name,"my BMI is :",BMI)
# Out:
# enter your weight 98
# enter your height1.9
# what is your nameabdul wahab shah
# my name is : abdul wahab shah my BMI is : 27.146814404432135

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic=sns.load_dataset("titanic")
# titanic
# sns.catplot(x="sex",y="survived",hue="class",kind="bar",data=titanic)
# plt.show()
sns.catplot(x="who",y="survived",hue="alone",kind="bar",data=titanic)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic=sns.load_dataset("titanic")
p1=sns.countplot(x="sex",hue="class",data=titanic)
p1.set_title("Plot for counting")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic=sns.load_dataset("titanic")
g=sns.FacetGrid(titanic,row="sex",hue="alone")
g=(g.map(plt.scatter,"age","fare").add_legend)
plt.show()
